# %% [markdown]
# Write a Python program to find the volume of a sphere with diameter 12 cm.
# Formula: V=4/3 * π * r
# 3

# %%
pi = 3.1415
r = 12

v = 4 * pi * r**3 / 3

print(str(v) + " cm^3")
# Out:
# 7238.0160000000005 cm^3
